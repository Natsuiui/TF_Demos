# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import regularizers

print(tf.__version__)
# Out:
# 2.11.0

# %%
import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots

# %%
from  IPython import display
from matplotlib import pyplot as plt

import numpy as np

import pathlib
import shutil
import tempfile

# %%
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

# %%
#HIGG'S DATASET

gz = tf.keras.utils.get_file('HIGGS.csv.gz', 'http://mlphysics.ics.uci.edu/data/higgs/HIGGS.csv.gz')

# %%
FEATURES = 28

# %%
ds = tf.data.experimental.CsvDataset(gz,[float(),]*(FEATURES+1), compression_type="GZIP")

# %%
def pack_row(*row):
    label = row[0]
    features = tf.stack(row[1:],1)
    return features, label

# %%
packed_ds = ds.batch(10000).map(pack_row).unbatch()

# %%
for features,label in packed_ds.batch(1000).take(1):
    print(features[0])
    plt.hist(features.numpy().flatten(), bins = 101)
# Out:
# 2023-02-16 18:13:20.714066: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# tf.Tensor(
# [ 0.8692932  -0.6350818   0.22569026  0.32747006 -0.6899932   0.75420225
#  -0.24857314 -1.0920639   0.          1.3749921  -0.6536742   0.9303491
#   1.1074361   1.1389043  -1.5781983  -1.0469854   0.          0.65792954
#  -0.01045457 -0.04576717  3.1019614   1.35376     0.9795631   0.97807616
#   0.92000484  0.72165745  0.98875093  0.87667835], shape=(28,), dtype=float32)

# %%
N_VALIDATION = 1000
N_TRAIN = 10000
BUFFER_SIZE = 10000
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
validate_ds = packed_ds.take(N_VALIDATION).cache()
train_ds = packed_ds.skip(N_VALIDATION).take(N_TRAIN).cache()

# %%
train_ds
# Out:
# <CacheDataset element_spec=(TensorSpec(shape=(28,), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.float32, name=None))>

# %%
validate_ds = validate_ds.batch(BATCH_SIZE)
train_ds = train_ds.shuffle(BUFFER_SIZE).repeat().batch(BATCH_SIZE)

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  0.001,
  decay_steps=STEPS_PER_EPOCH*1000,
  decay_rate=1,
  staircase=False)

def get_optimizer():
    return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %%
def get_callbacks(name):
    return [
        tfdocs.modeling.EpochDots(),
        tf.keras.callbacks.EarlyStopping(monitor='val_binary_crossentropy', patience=200),
        tf.keras.callbacks.TensorBoard(logdir/name),
    ]

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
    if optimizer is None:
        optimizer = get_optimizer()
    model.compile(optimizer=optimizer,
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=[
                  tf.keras.metrics.BinaryCrossentropy(
                      from_logits=True, name='binary_crossentropy'),
                  'accuracy'])

    model.summary()

    history = model.fit(
        train_ds,
        steps_per_epoch = STEPS_PER_EPOCH,
        epochs=max_epochs,
        validation_data=validate_ds,
        callbacks=get_callbacks(name),
        verbose=0)
    return history

# %%
tiny_model = tf.keras.Sequential([
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(1)
])

# %%
size_histories = {}

# %%
size_histories['Tiny'] = compile_and_fit(tiny_model, 'sizes/Tiny')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                464
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-16 21:11:51.973146: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:392] Filling up shuffle buffer (this may take a while): 9999 of 10000
# 2023-02-16 21:11:51.974677: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:417] Shuffle buffer filled.
# Epoch: 0, accuracy:0.4943,  binary_crossentropy:0.8143,  loss:0.8143,  val_accuracy:0.4850,  val_binary_crossentropy:0.7946,  val_loss:0.7946,
# ....................................................................................................
# Epoch: 100, accuracy:0.5984,  binary_crossentropy:0.6269,  loss:0.6269,  val_accuracy:0.5790,  val_binary_crossentropy:0.6274,  val_loss:0.6274,
# ....................................................................................................
# Epoch: 200, accuracy:0.6317,  binary_crossentropy:0.6086,  loss:0.6086,  val_accuracy:0.6160,  val_binary_crossentropy:0.6073,  val_loss:0.6073,
# ....................................................................................................
# Epoch: 300, accuracy:0.6487,  binary_crossentropy:0.5991,  loss:0.5991,  val_accuracy:0.6400,  val_binary_crossentropy:0.5935,  val_loss:0.5935,
# ....................................................................................................
# Epoch: 400, accuracy:0.6592,  binary_crossentropy:0.5941,  loss:0.5941,  val_accuracy:0.6520,  val_binary_crossentropy:0.5879,  val_loss:0.5879,
# ....................................................................................................
# Epoch: 500, accuracy:0.6631,  binary_crossentropy:0.5899,  loss:0.5899,  val_accuracy:0.6520,  val_binary_crossentropy:0.5886,  val_loss:0.5886,
# ....................................................................................................
# Epoch: 600, accuracy:0.6674,  binary_crossentropy:0.5866,  loss:0.5866,  val_accuracy:0.6720,  val_binary_crossentropy:0.5851,  val_loss:0.5851,
# ....................................................................................................
# Epoch: 700, accuracy:0.6670,  binary_crossentropy:0.5850,  loss:0.5850,  val_accuracy:0.6630,  val_binary_crossentropy:0.5858,  val_loss:0.5858,
# ....................................................................................................
# Epoch: 800, accuracy:0.6686,  binary_crossentropy:0.5828,  loss:0.5828,  val_accuracy:0.6780,  val_binary_crossentropy:0.5846,  val_loss:0.5846,
# ....................................................................................................
# Epoch: 900, accuracy:0.6748,  binary_crossentropy:0.5809,  loss:0.5809,  val_accuracy:0.6520,  val_binary_crossentropy:0.5869,  val_loss:0.5869,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6764,  binary_crossentropy:0.5791,  loss:0.5791,  val_accuracy:0.6730,  val_binary_crossentropy:0.5842,  val_loss:0.5842,
# ....................................................................................................
# Epoch: 1100, accuracy:0.6779,  binary_crossentropy:0.5774,  loss:0.5774,  val_accuracy:0.6700,  val_binary_crossentropy:0.5841,  val_loss:0.5841,
# ....................................................................................................
# Epoch: 1200, accuracy:0.6783,  binary_crossentropy:0.5760,  loss:0.5760,  val_accuracy:0.6650,  val_binary_crossentropy:0.5856,  val_loss:0.5856,
# .............................................................................................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
small_model = tf.keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    layers.Dense(16, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(16, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Small'] = compile_and_fit(small_model, 'sizes/Small')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 16)                464
#
#  dense_3 (Dense)             (None, 16)                272
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 753
# Trainable params: 753
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4697,  binary_crossentropy:0.7440,  loss:0.7440,  val_accuracy:0.4580,  val_binary_crossentropy:0.7353,  val_loss:0.7353,
# ....................................................................................................
# Epoch: 100, accuracy:0.6267,  binary_crossentropy:0.6110,  loss:0.6110,  val_accuracy:0.6200,  val_binary_crossentropy:0.6158,  val_loss:0.6158,
# ....................................................................................................
# Epoch: 200, accuracy:0.6615,  binary_crossentropy:0.5884,  loss:0.5884,  val_accuracy:0.6490,  val_binary_crossentropy:0.5983,  val_loss:0.5983,
# ....................................................................................................
# Epoch: 300, accuracy:0.6778,  binary_crossentropy:0.5782,  loss:0.5782,  val_accuracy:0.6570,  val_binary_crossentropy:0.5902,  val_loss:0.5902,
# ....................................................................................................
# Epoch: 400, accuracy:0.6815,  binary_crossentropy:0.5720,  loss:0.5720,  val_accuracy:0.6830,  val_binary_crossentropy:0.5851,  val_loss:0.5851,
# ....................................................................................................
# Epoch: 500, accuracy:0.6852,  binary_crossentropy:0.5664,  loss:0.5664,  val_accuracy:0.6810,  val_binary_crossentropy:0.5839,  val_loss:0.5839,
# ....................................................................................................
# Epoch: 600, accuracy:0.6881,  binary_crossentropy:0.5616,  loss:0.5616,  val_accuracy:0.6830,  val_binary_crossentropy:0.5802,  val_loss:0.5802,
# ....................................................................................................
# Epoch: 700, accuracy:0.6951,  binary_crossentropy:0.5583,  loss:0.5583,  val_accuracy:0.6730,  val_binary_crossentropy:0.5824,  val_loss:0.5824,
# ....................................................................................................
# Epoch: 800, accuracy:0.6978,  binary_crossentropy:0.5550,  loss:0.5550,  val_accuracy:0.6790,  val_binary_crossentropy:0.5800,  val_loss:0.5800,
# ....................................................................................................
# Epoch: 900, accuracy:0.7019,  binary_crossentropy:0.5523,  loss:0.5523,  val_accuracy:0.6800,  val_binary_crossentropy:0.5794,  val_loss:0.5794,
# ....................................................................................................
# Epoch: 1000, accuracy:0.7020,  binary_crossentropy:0.5500,  loss:0.5500,  val_accuracy:0.6660,  val_binary_crossentropy:0.5837,  val_loss:0.5837,
# ....................................................................................................
# Epoch: 1100, accuracy:0.7033,  binary_crossentropy:0.5469,  loss:0.5469,  val_accuracy:0.6810,  val_binary_crossentropy:0.5791,  val_loss:0.5791,
# .......

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
medium_model = tf.keras.Sequential([
    layers.Dense(64, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(64, activation='elu'),
    layers.Dense(64, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['Medium']  = compile_and_fit(medium_model, "sizes/Medium")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                1856
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 10,241
# Trainable params: 10,241
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4805,  binary_crossentropy:0.7283,  loss:0.7283,  val_accuracy:0.4600,  val_binary_crossentropy:0.6936,  val_loss:0.6936,
# ....................................................................................................
# Epoch: 100, accuracy:0.7093,  binary_crossentropy:0.5365,  loss:0.5365,  val_accuracy:0.6570,  val_binary_crossentropy:0.6057,  val_loss:0.6057,
# ....................................................................................................
# Epoch: 200, accuracy:0.7790,  binary_crossentropy:0.4408,  loss:0.4408,  val_accuracy:0.6650,  val_binary_crossentropy:0.6688,  val_loss:0.6688,
# ......................................................................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
large_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(512, activation='elu'),
    layers.Dense(1)
])

# %%
size_histories['large'] = compile_and_fit(large_model, "sizes/large")
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 512)               14848
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dense_11 (Dense)            (None, 512)               262656
#
#  dense_12 (Dense)            (None, 512)               262656
#
#  dense_13 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5081,  binary_crossentropy:0.7755,  loss:0.7755,  val_accuracy:0.4790,  val_binary_crossentropy:0.6907,  val_loss:0.6907,
# ....................................................................................................
# Epoch: 100, accuracy:1.0000,  binary_crossentropy:0.0022,  loss:0.0022,  val_accuracy:0.6660,  val_binary_crossentropy:1.8164,  val_loss:1.8164,
# ....................................................................................................
# Epoch: 200, accuracy:1.0000,  binary_crossentropy:0.0001,  loss:0.0001,  val_accuracy:0.6560,  val_binary_crossentropy:2.4711,  val_loss:2.4711,
# .....................

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'binary_crossentropy', smoothing_std=10)
plotter.plot(size_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
plotter.plot(size_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0.5, 0.7])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir {logdir}/sizes
# Out:
#       <iframe id="tensorboard-frame-c91f685e02f540db" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c91f685e02f540db");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
shutil.rmtree(logdir/'regularizers/Tiny', ignore_errors=True)
shutil.copytree(logdir/'sizes/Tiny', logdir/'regularizers/Tiny')
# Out:
# PosixPath('/var/folders/vm/4d22p22d2xn2spd1hbvqv2tm0000gn/T/tmp63bsy_y1/tensorboard_logs/regularizers/Tiny')

# %%
regularizer_histories = {}
regularizer_histories['Tiny'] = size_histories['Tiny']

# %%
l2_model = tf.keras.Sequential([
    layers.Dense(512, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001),
                 input_shape=(FEATURES,)),
    layers.Dense(512, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(512, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1)
])

regularizer_histories['l2'] = compile_and_fit(l2_model, "regularizers/l2")
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 512)               14848
#
#  dense_20 (Dense)            (None, 512)               262656
#
#  dense_21 (Dense)            (None, 512)               262656
#
#  dense_22 (Dense)            (None, 512)               262656
#
#  dense_23 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4829,  binary_crossentropy:0.6879,  loss:1.9165,  val_accuracy:0.4700,  val_binary_crossentropy:0.6778,  val_loss:1.5573,
# ....................................................................................................
# Epoch: 100, accuracy:0.4738,  binary_crossentropy:0.6925,  loss:0.8054,  val_accuracy:0.4600,  val_binary_crossentropy:0.6920,  val_loss:0.8015,
# ....................................................................................................
# Epoch: 200, accuracy:0.4738,  binary_crossentropy:0.6918,  loss:0.7121,  val_accuracy:0.4600,  val_binary_crossentropy:0.6905,  val_loss:0.7107,
# ................

# %%
plotter.plot(regularizer_histories)
a = plt.xscale('log')
plt.xlim([5, max(plt.xlim())])
plt.ylim([0, 1])
plt.xlabel("Epochs [Log Scale]")
# Out:
# Text(0.5, 0, 'Epochs [Log Scale]')

# %%
dropout_model = tf.keras.Sequential([
    layers.Dense(512, activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['dropout'] = compile_and_fit(dropout_model, "regularizers/dropout")combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 512)               14848
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_25 (Dense)            (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_26 (Dense)            (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_27 (Dense)            (None, 512)               262656
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_28 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.4961,  binary_crossentropy:0.8068,  loss:0.8068,  val_accuracy:0.5530,  val_binary_crossentropy:0.7191,  val_loss:0.7191,
# ....................................................................................................
# Epoch: 100, accuracy:0.6594,  binary_crossentropy:0.5960,  loss:0.5960,  val_accuracy:0.6900,  val_binary_crossentropy:0.5791,  val_loss:0.5791,
# ....................................................................................................
# Epoch: 200, accuracy:0.6846,  binary_crossentropy:0.5596,  loss:0.5596,  val_accuracy:0.7010,  val_binary_crossentropy:0.5884,  val_loss:0.5884,
# ....................................................................................................
# Epoch: 300, accuracy:0.7237,  binary_crossentropy:0.5099,  loss:0.5099,  val_accuracy:0.6880,  val_binary_crossentropy:0.5975,  val_loss:0.5975,
# .....................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu', input_shape=(FEATURES,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='elu'),
    layers.Dropout(0.5),
    layers.Dense(1)
])

regularizer_histories['combined'] = compile_and_fit(combined_model, "regularizers/combined")
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_29 (Dense)            (None, 512)               14848
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_30 (Dense)            (None, 512)               262656
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_31 (Dense)            (None, 512)               262656
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_32 (Dense)            (None, 512)               262656
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_33 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 803,329
# Trainable params: 803,329
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch: 0, accuracy:0.5126,  binary_crossentropy:0.7882,  loss:0.9463,  val_accuracy:0.5580,  val_binary_crossentropy:0.6713,  val_loss:0.8288,
# ....................................................................................................
# Epoch: 100, accuracy:0.6472,  binary_crossentropy:0.6036,  loss:0.6325,  val_accuracy:0.6400,  val_binary_crossentropy:0.5920,  val_loss:0.6206,
# ....................................................................................................
# Epoch: 200, accuracy:0.6605,  binary_crossentropy:0.5919,  loss:0.6170,  val_accuracy:0.6810,  val_binary_crossentropy:0.5701,  val_loss:0.5953,
# ....................................................................................................
# Epoch: 300, accuracy:0.6668,  binary_crossentropy:0.5842,  loss:0.6122,  val_accuracy:0.6730,  val_binary_crossentropy:0.5752,  val_loss:0.6032,
# ....................................................................................................
# Epoch: 400, accuracy:0.6719,  binary_crossentropy:0.5783,  loss:0.6079,  val_accuracy:0.6950,  val_binary_crossentropy:0.5594,  val_loss:0.5890,
# ....................................................................................................
# Epoch: 500, accuracy:0.6804,  binary_crossentropy:0.5747,  loss:0.6061,  val_accuracy:0.6970,  val_binary_crossentropy:0.5495,  val_loss:0.5809,
# ....................................................................................................
# Epoch: 600, accuracy:0.6799,  binary_crossentropy:0.5675,  loss:0.6007,  val_accuracy:0.6940,  val_binary_crossentropy:0.5509,  val_loss:0.5841,
# ....................................................................................................
# Epoch: 700, accuracy:0.6853,  binary_crossentropy:0.5632,  loss:0.5976,  val_accuracy:0.6930,  val_binary_crossentropy:0.5479,  val_loss:0.5824,
# ....................................................................................................
# Epoch: 800, accuracy:0.6876,  binary_crossentropy:0.5592,  loss:0.5950,  val_accuracy:0.7000,  val_binary_crossentropy:0.5511,  val_loss:0.5869,
# ....................................................................................................
# Epoch: 900, accuracy:0.6980,  binary_crossentropy:0.5536,  loss:0.5907,  val_accuracy:0.6900,  val_binary_crossentropy:0.5397,  val_loss:0.5767,
# ....................................................................................................
# Epoch: 1000, accuracy:0.6990,  binary_crossentropy:0.5529,  loss:0.5914,  val_accuracy:0.7160,  val_binary_crossentropy:0.5374,  val_loss:0.5759,
# ...........................................................

# %%
plotter.plot(regularizer_histories)
plt.ylim([0.5, 0.7])
# Out:
# (0.5, 0.7)
